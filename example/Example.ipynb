# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = numpy.array([2**x for x in range(0, 31)])
y1 = numpy.linspace(0, 30000, 31) * (1 + numpy.random.random(31)) * 2
y2 = numpy.linspace(0, 35000, 31) * (1 + numpy.random.random(31)) * 3

# %%
plt.semilogx(x, y1, basex=2)
plt.semilogx(x, y2, basex=2)
plt.title("Foobar Performance")
plt.ylabel("Foodicity [Baz/second]")
plt.xlabel("Size")

plt.savefig('example_plain.png')

# %%
plt.semilogx(x, y1, basex=2)
plt.semilogx(x, y2, basex=2)
plt.title("Foobar Performance")
plt.ylabel("Foodicity [Baz/second]")
plt.xlabel("Size")

import prettyplot
prettyplot.config_plot(plt.gca())
prettyplot.natural_log2_xaxis(plt.gca(), [ 2])

plt.savefig('example_prettyplot.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-93be3e2202be> in <module>()
#       7 import prettyplot
#       8 prettyplot.config_plot(plt.gca())
# ----> 9 prettyplot.natural_log2_xaxis(plt.gca(), plt.gca().axes.xaxis.ticks())
#      10
#      11 plt.savefig('example_prettyplot.png')
#
# AttributeError: 'XAxis' object has no attribute 'ticks'
